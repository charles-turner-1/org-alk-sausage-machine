# %%
import SausageMachine


tit = SausageMachine.org_alk_titration("~/Python/org-alk-sausage-machine")

tit.read_excel_spreadsheets("01.09.21.50UM.001_PROCESSED.xlsx",
                            "01.09.21.50UM.001.NAOH_PROCESSED.xlsx",
                            "01.09.21.50UM.001.BT_PROCESSED.xlsx")

tit.pipeline()
tit.init_minimiser()
tit.dissociation_consts()



tit2 = SausageMachine.org_alk_titration()

tit2.titrate(masterFile = "aklsdjflkasdjf.xlsx", name = "dublin_bay_site_4", plot=True)
tit2.write_to_excel()
# Out:
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:413: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe["pH"] = -np.log10(np.exp((dataframe["E(V)"]-E0_final)/dataframe["K"])) #CALCULATE pH AT EACH TITRATION POINT FROM E0 FINAL ESTIMATE
# TA :  83.84526363461985 µmol.kg-1
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:413: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe["pH"] = -np.log10(np.exp((dataframe["E(V)"]-E0_final)/dataframe["K"])) #CALCULATE pH AT EACH TITRATION POINT FROM E0 FINAL ESTIMATE
# BT :  55.945681029064296 µmol.kg-1
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:413: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe["pH"] = -np.log10(np.exp((dataframe["E(V)"]-E0_final)/dataframe["K"])) #CALCULATE pH AT EACH TITRATION POINT FROM E0 FINAL ESTIMATE
# TA :  83.84526363461985 µmol.kg-1
# BT :  55.945681029064296 µmol.kg-1
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:413: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe["pH"] = -np.log10(np.exp((dataframe["E(V)"]-E0_final)/dataframe["K"])) #CALCULATE pH AT EACH TITRATION POINT FROM E0 FINAL ESTIMATE

# %%
tit.repeat_minimise(1,1e-8)
# Out:
# Minimisation repeated 1 times in order to reach fractional change of 1e-08 in SSR
# Final SSR value = 0.00397
# X1 (initial): 90.7777132532761 | pK1(initial):  5.259797138994193 | H0 : 0.0006988474973753943

# %%
tit.repeat_minimise(2,1e-8)
# Out:
# Minimisation repeated 1 times in order to reach fractional change of 1e-08 in SSR
# Final SSR value = 0.00112
# X1: 36.40531806246138 | pK1:  4.857198851342073 | Deviation % (g) NaOH : 0.235162544701127

# %%
tit.repeat_minimise(3,1e-8)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /Users/ct6g18/Python/org-alk-sausage-machine/Test_Notebook.ipynb Cell 4' in <module>
# ----> <a href='vscode-notebook-cell:/Users/ct6g18/Python/org-alk-sausage-machine/Test_Notebook.ipynb#ch0000003?line=0'>1</a> tit.repeat_minimise(3,1e-8)
#
# File ~/Python/org-alk-sausage-machine/SausageMachine.py:713, in org_alk_titration.repeat_minimise(self, minimiser_no, SSR_frac_change_limit, plot_results)
#     <a href='file:///~/Python/org-alk-sausage-machine/SausageMachine.py?line=710'>711</a> while SSR_frac_change > SSR_frac_change_limit:
#     <a href='file:///~/Python/org-alk-sausage-machine/SausageMachine.py?line=711'>712</a>     if num_reps > 1000:
# --> <a href='file:///~/Python/org-alk-sausage-machine/SausageMachine.py?line=712'>713</a>         raise Exception("This doesn't look like its going to work after 1000 repetitions")
#     <a href='file:///~/Python/org-alk-sausage-machine/SausageMachine.py?line=713'>714</a>     self.minimise(minimiser_no)
#     <a href='file:///~/Python/org-alk-sausage-machine/SausageMachine.py?line=714'>715</a>     SSR = self.ssr(minimiser_no)
#
# Exception: This doesn't look like its going to work after 1000 repetitions

# %%
tit.repeat_minimise(4,1e-10)
