# %%
os.chdir("/Users/ct6g18/Python/org-alk-sausage-machine")

# %%
import SausageMachine
tit1 = SausageMachine.OrgAlkTitration()
tit2 = SausageMachine.OrgAlkTitration()
tit1.read_master_spreadsheet("~/Python/org-alk-sausage-machine/Test_Spreadsheets"
                           ,"Master_Tit_File_updated.xlsx"
                           ,"01.09.21.50UM.001_PROCESSED.xlsx")
tit1.pipeline()

tit2.read_master_spreadsheet("~/Python/org-alk-sausage-machine/Test_Spreadsheets"
                           ,"Master_Tit_File_updated.xlsx"
                           ,"01.09.21.50UM.002_PROCESSED.xlsx")
tit2.pipeline()
# Out:
# TA :  83.84526363461985 µmol.kg-1
# OA :  55.945681029064296 µmol.kg-1
# TA :  81.89069676430981 µmol.kg-1
# OA :  52.80770140718645 µmol.kg-1

# %%
tit1.species_concentrations["CTNa"]
# Out:
# 0.0

# %%
tit1.repeat_minimise(SSR_frac_change_limit=1e-8,minimiser_no=1,plot_results=False)
# Out:
# Minimisation repeated 1 times in order to reach fractional change of 1e-08 in SSR
# Final SSR value = 0.00383
# X1 (initial): 90.7777132532761 | pK1(initial):  5.259797138994193 | H0 : 0.0006988474973753943

# %%
tit2.repeat_minimise(2,1e-8)
# Out:
# Minimisation repeated 2 times in order to reach fractional change of 1e-08 in SSR
# Final SSR value = 0.00100
# X1: 49.18227265827269 | pK1:  4.888739345535772 | Deviation % (g) NaOH : 0.21083778325131372

# %%
tit2.repeat_minimise(3,1e-8)
# Out:
# Minimisation repeated 1 times in order to reach fractional change of 1e-08 in SSR
# Final SSR value = 0.00100
# X2: -0.11856704926529067 | pK2:  nan | Deviation % (g) NaOH : 0.2104337895370222
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:598: RuntimeWarning: invalid value encountered in log10
#   pK2 = -np.log10(self.K_X2)
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:598: RuntimeWarning: invalid value encountered in log10
#   pK2 = -np.log10(self.K_X2)
# /Users/ct6g18/Python/org-alk-sausage-machine/SausageMachine.py:817: RuntimeWarning: invalid value encountered in log10
#   print('X2:', self.X2*10**6, "| pK2: ", -np.log10(self.K_X2), '| Deviation % (g) NaOH :', (SSR/self.Vb)*100 )

# %%
tit2.repeat_minimise(4,1e-10)
# Out:
# Minimisation repeated 43 times in order to reach fractional change of 1e-10 in SSR
# Final SSR value = 0.00100
# X3: 12392.214916631126 | pK3:  11.978739216372917 | Deviation % (g) NaOH : 0.21043342188710318

# %%
tit.repeat_minimise(4,1e-10)
# Out:
# Minimisation repeated 35 times in order to reach fractional change of 1e-10 in SSR
# Final SSR value = 0.00113
# X3: 5575.380797424332 | pK3:  11.631899166213637 | Deviation % (g) NaOH : 0.2369874544095991
